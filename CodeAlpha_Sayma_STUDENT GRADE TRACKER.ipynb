# %%
pip install dash
# Out:
# Requirement already satisfied: dash in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (2.18.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from dash) (3.0.4)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from dash) (5.23.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from dash) (8.4.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from dash) (74.1.2)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (1.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from plotly>=5.0.0->dash) (9.0.0)
# Requirement already satisfied: packaging in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from plotly>=5.0.0->dash) (24.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from Werkzeug<3.1->dash) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from importlib-metadata->dash) (3.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from requests->dash) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from requests->dash) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from requests->dash) (2024.8.30)
# Requirement already satisfied: six>=1.7.0 in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: colorama in c:\users\pc\desktop\data science kais\.venv\lib\site-packages (from click>=8.1.3->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output, State
import pandas as pd

# Create a Dash application
app = dash.Dash(__name__)

# Initialize a DataFrame to store grades
data = pd.DataFrame(columns=["Student", "Subject", "Grade", "Coefficient"])

# Layout of the application
app.layout = html.Div([
    html.H1("Student Grade Tracker"),
    
    html.Div([
        html.Label("Student Name:"),
        dcc.Input(id='student-name', type='text', placeholder='Enter student name'),
    ]),
    
    html.Div([
        html.Label("Subject:"),
        dcc.Input(id='subject-name', type='text', placeholder='Enter subject'),
    ]),
    
    html.Div([
        html.Label("Grade:"),
        dcc.Input(id='grade', type='number', placeholder='Enter grade', min=0, max=20),
    ]),
    
    html.Div([
        html.Label("Coefficient:"),
        dcc.Input(id='coefficient', type='number', placeholder='Enter coefficient', min=0, step=0.1),
    ]),
    
    html.Button('Add Grade', id='submit-button', n_clicks=0),
    
    html.Hr(),
    
    html.H3("Student Grades"),
    html.Div(id='table-container'),
    
    html.Hr(),
    
    html.H3("Weighted Average Grades by Student"),
    html.Div(id='average-container')
])

# Callback to add grades and display data
@app.callback(
    [Output('table-container', 'children'),
     Output('average-container', 'children')],
    [Input('submit-button', 'n_clicks')],
    [State('student-name', 'value'),
     State('subject-name', 'value'),
     State('grade', 'value'),
     State('coefficient', 'value')]
)
def update_table(n_clicks, student_name, subject_name, grade, coefficient):
    global data
    if n_clicks > 0 and student_name and subject_name and grade is not None and coefficient is not None:
        # Add the new grade to the DataFrame
        new_data = pd.DataFrame({'Student': [student_name], 'Subject': [subject_name], 'Grade': [grade], 'Coefficient': [coefficient]})
        data = pd.concat([data, new_data], ignore_index=True)
        
        # Create a table of grades
        table = html.Table([
            html.Thead(html.Tr([html.Th(col) for col in data.columns])),
            html.Tbody([
                html.Tr([html.Td(data.iloc[i][col]) for col in data.columns]) for i in range(len(data))
            ])
        ])
        
        # Calculate weighted average grades by student
        averages = data.groupby('Student').apply(
            lambda x: (x['Grade'] * x['Coefficient']).sum() / x['Coefficient'].sum()
        ).reset_index(name='Weighted Average')
        
        average_table = html.Table([
            html.Thead(html.Tr([html.Th(col) for col in averages.columns])),
            html.Tbody([
                html.Tr([html.Td(averages.iloc[i][col]) for col in averages.columns]) for i in range(len(averages))
            ])
        ])
        
        return table, average_table
    return html.Div(), html.Div()

# Run the application on a specific port
if __name__ == '__main__':
    app.run_server(debug=True, port=8051)  # Change the port if necessary


# http://127.0.0.1:8051/
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# C:\Users\PC\AppData\Local\Temp\ipykernel_16004\3339418156.py:75: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# C:\Users\PC\AppData\Local\Temp\ipykernel_16004\3339418156.py:75: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# C:\Users\PC\AppData\Local\Temp\ipykernel_16004\3339418156.py:75: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# C:\Users\PC\AppData\Local\Temp\ipykernel_16004\3339418156.py:75: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# C:\Users\PC\AppData\Local\Temp\ipykernel_16004\3339418156.py:75: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# C:\Users\PC\AppData\Local\Temp\ipykernel_16004\3339418156.py:75: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# C:\Users\PC\AppData\Local\Temp\ipykernel_16004\3339418156.py:75: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# C:\Users\PC\AppData\Local\Temp\ipykernel_16004\3339418156.py:75: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# C:\Users\PC\AppData\Local\Temp\ipykernel_16004\3339418156.py:75: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# C:\Users\PC\AppData\Local\Temp\ipykernel_16004\3339418156.py:75: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# C:\Users\PC\AppData\Local\Temp\ipykernel_16004\3339418156.py:75: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# C:\Users\PC\AppData\Local\Temp\ipykernel_16004\3339418156.py:75: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# C:\Users\PC\AppData\Local\Temp\ipykernel_16004\3339418156.py:75: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
